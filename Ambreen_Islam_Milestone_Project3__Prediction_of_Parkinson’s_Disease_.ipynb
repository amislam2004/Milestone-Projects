# %% [markdown]
# <a href="https://colab.research.google.com/github/amislam2004/Milestone-Projects/blob/main/Ambreen_Islam_Milestone_Project3__Prediction_of_Parkinson%E2%80%99s_Disease_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Milestone Project 3
#
# ##Part 1: Planning

# %% [markdown]
# ### Task 1: Choose a Research Question
#
# For this task, we're going to focus on formulating a research question with a compelling, real-world application that can be answered using a machine learning model. There is no specific area or topic that you're required to investigate.  In fact, it's usually more interesting if you're exploring your own personal interests or answering a question related to the industry where you will direct your job search.

# %% [markdown]
# **The most important rule of research questions is to actually have one.** Many, many projects suffer because the learner begins with a vague, general sense of direction but doesn’t have a clear, specific question to answer.  For example, you might wish to complete your Milestone 3 project about shopping habits at a particular online retailer, but the data you use and the ML model you develop will depend on your specific research question.
#
# For example, you’ll need different methods to answer the question “Are customers who see a new version of the store website more likely to make a purchase?” than to answer the question, “What products do customers often purchase in the same order?”

# %% [markdown]
# **The second most important rule of research questions is not to get in over your head.**  If you are really interested in your topic, you will probably have lots and lots of research questions that you are tempted to answer with this project.  Do not do it!  For this project, you will answer one (and only one) specific, well-defined question.

# %% [markdown]
# Research is not a mechanical process and often doesn’t proceed in a straight line, but it's almost always best to spend time at the start of your project developing and refining a core question that will motivate your study: it makes every aspect of the research process easier.
#
#
# **Although you may need to try a lot of things on your way to answering your research question, please remove any code that is not part of your finished project before submitting.**
#
# **This notebook should be able to run from start to finish without error.**

# %% [markdown]
# **Step 1**
#
# Healthcare Industry: Diabetes/ Parkinsons/ Cancer/ Heart Disease
#
# # ***Question?***
#
# Can I build a healthcare model to accurately detect the presence of Parkinsons disease in an individual using XGBoost Classifier which can be more accurate and has no false negative values? XGBooster Classifier is a modern Machine Learning alogrithm designed for eXtreme Gradient Boosting and is based on decision trees, In this project we will be using xgboost library to implement XGBooster Classifier.
#
#
# Earthquake Prediction Research: Research seismologists study the internal structure of the Earth and try to determine factors that contribute to or foretell an earthquake.
# Which model serve the best to predict the earthquake where it most likely expected?

# %% [markdown]
# **Step 1 Answer**
#
# Healthcare Industry: Diabetes/ Parkinsons/ Cancer/ Heart Disease
#
# Earthquake Prediction Research: Research seismologists study the internal structure of the Earth and try to determine factors that contribute to or foretell an earthquake.

# %% [markdown]
# **Step 2**
#
# Pick the industry or topic from Step 1 that interests you the most.  Brainstorm three potential research questions that you could answer for this project.  **Right now, the question will be fairly broad.  You will refine your research question once you select your data set.**  Each potential research question should have the following qualities:
#
# *   It's a question, not a statement.
#
#   ***Can I build a healthcare model to accurately detect the presence of Parkinsons disease in an individual using XGBoost Classifier which can be more accurate and has no false negative values?***
#
# *   It has a real-world application with clear stakeholder(s).
#
#   ***Patient participants and their family members, nurse care managers, Parkinson disease (PD) specialists, caregivers, researchers etc.***
#
# *   You can answer the question using a machine learning model.
#
#   ***XGBooster Classifier is a modern Machine Learning alogrithm designed for eXtreme Gradient Boosting and is based on decision trees, In this project we will be using xgboost library to implement XGBooster Classifier.***
#
# *   You know (or have a pretty good idea) which machine learning model will be appropriate for your research question. ***No***
#
# *   You have a pretty good idea how to find the data that will answer your question (more on that later). ***Yes***
#
# *   You don't know the answer in advance. ***I need to apply the models before evaluating the models and compare all of them to optimize the accuracy. Then apply the XGBooster Classifier.***

# %% [markdown]
# **Step 3**
#
# Rank your three potential research questions from Step 2 in order from one to three with one being your top choice and two and three being backup choices.
#
# When ranking your research questions, think both about what interests you the most and what will be practical.  How well-defined is each research question?  How difficult will it be to find data to answer that question?  How difficult will it be to wrangle the data?  How confident do you feel about selecting an ML model to answer the research question?
#
# This is a great time to involve your instructor, who can provide guidance on revising your ideas in Step 2 and identifying your top and backup research questions.

# %% [markdown]
# **Step 3 Answer**
#
# Write your answer for Step 3 here.

# %% [markdown]
# **My Milestone Project 3 Research Question Is:**
#
# Write your Milestone Project 3 Research Question here.

# %% [markdown]
# ### Task 2: Select a Data Set
#
# Once you have a research question, you need to find a publically available data set that will allow you to answer it.

# %% [markdown]
# There are lots of potential sources.  A few that are particularly useful are:
#
# Awesome public data sets: https://github.com/awesomedata/awesome-public-datasets
#
# Kaggle: https://www.kaggle.com/datasets
#
# UC Irvine Machine Learning: https://archive.ics.uci.edu/ml/datasets.php
#
# Definitely Google around for more data sources and ask your peers and instructor!

# %%
## Step 1: Importing the Dependencies
## The dependencies are the libraries and the functions which we need for the project. 
# import warnings
# warnings.filterwarnings('ignore')
import pandas as pd
import os,sys
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression, Lasso, RidgeClassifier, Ridge, LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report, auc, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE
import numpy as np
import seaborn as sns
from sklearn import svm

# %% [markdown]
# **Step 1**
#
# Find at least one data set that you can use to answer your research question from Task 1.
#
# Your data set should:
# * Be at least 100 records long.  You'll need a lot more records if you want to use a neural network.
# * Be publicly available on the Internet. Don't collect your own data.  Don’t use data that can’t be attributed to a reputable source.
# * Have at least four features (remember that, when modeling text data, each word is a feature).
#
# This is another good opportunity to check in with your instructor and make sure you are on the right track.

# %%
#Step 2 
# Load Data

from google.colab import files
segmentation = files.upload()
# Out:
#      <input type="file" id="files-103a76c1-f871-4c16-8d14-fd9a809527c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-103a76c1-f871-4c16-8d14-fd9a809527c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Step 1 Answer**
#
# Write a short description of your data set and it's location (URL or where you saved it on your computer) here.
# "C:\Users\amisl\OneDrive\Desktop\Final_Milestone Project_Ambreen Islam"

# %%
# loading the data from csv file to a Pandas DataFrame
parkinsons_data= pd.read_csv('parkinsons.csv')

# %% [markdown]
# ### Task 3: Conduct Exploratory Data Analysis
#
# The purpose of exploratory data analysis at the project planning stage is to make sure that your data will answer your research question. It is possible to do everything correctly during this step and still hit a roadblock when you actually run your ML model, but it’s much less likely.

# %%
## Length of the Dataset
len(parkinsons_data)
# Out:
# 195

# %%
# printing the first 5 rows of the dataframe
parkinsons_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# number of rows and columns in the dataframe
parkinsons_data.shape
# Out:
# (195, 24)

# %%
# sns.pairplot(data=parkinsons_data) 
# this code works in Jupiter Noteboob

# %%
# getting more information about the dataset
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
for i in parkinsons_data.columns:
    print("**********************", i, "*************************")
    print()
    print(set(parkinsons_data[i].tolist()))
    print()
# Out:
# ********************** name *************************
#
# ...

# %%
parkinsons_data.hist(figsize=(15,15), layout = (5,5))
# Out:
# array([[<Axes: title={'center': 'MDVP:Fo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Fhi(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Flo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(%)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(Abs)'}>],
#        [<Axes: title={'center': 'MDVP:RAP'}>,
#         <Axes: title={'center': 'MDVP:PPQ'}>,
#         <Axes: title={'center': 'Jitter:DDP'}>,
#         <Axes: title={'center': 'MDVP:Shimmer'}>,
#         <Axes: title={'center': 'MDVP:Shimmer(dB)'}>],
#        [<Axes: title={'center': 'Shimmer:APQ3'}>,
#         <Axes: title={'center': 'Shimmer:APQ5'}>,
#         <Axes: title={'center': 'MDVP:APQ'}>,
#         <Axes: title={'center': 'Shimmer:DDA'}>,
#         <Axes: title={'center': 'NHR'}>],
#        [<Axes: title={'center': 'HNR'}>,
#         <Axes: title={'center': 'status'}>,
#         <Axes: title={'center': 'RPDE'}>,
#         <Axes: title={'center': 'DFA'}>,
#         <Axes: title={'center': 'spread1'}>],
# ...

# %%
import matplotlib.pyplot as plt
# Check Label Imbalance
temp=parkinsons_data["status"].value_counts()
temp_parkinsons_data=pd.DataFrame({'status':temp.index,'values':temp.values})
print(sns.barplot(x='status', y="values",data=temp_parkinsons_data))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### Task 4: Develop a Project Plan
#
# Now you are ready to plan out everything that will be in your final project slide deck. Yes

# %% [markdown]
# **Step 1 Answer**
# # ***Problem Statement***
# Parkinson's Diseases Detection
# Parkinson's diseases is a progressive nervous system disorder that affect movement leading to shaking, stiffness, and difficulty with walking, balance, and brain-body coordination. In this problem we have to predict whether the person is suffering from parkinson's diseases or not.
#
#
# # ***Real World Application***
#
# In this project, I created a Machine Learning model using XGBClassifier to Detect Parkinsons Disease with eXtreme Gradient Boosting (XGBoost) because accuracy alone is not enough to evaluate the healthcare models since false negative can be very problematic; for instance, person will have disease when diagnosed negative. Also, false positive can be a huge issue in sense of medication; person will be starting the medication when it is not needed.
#
# # ***Stakeholders***
#
#   ***Patient participants and their family members, nurse care managers, Parkinson disease (PD) specialists, caregivers, researchers etc.***

# %% [markdown]
# **Step 2**
#
# Are there any requirements your data must meet to use the ML model(s) you listed in Step 1?  For example, if you plan to use a logistic regression model, you must have a categorical target.  If you wish to use natural language processing, you'll need a large amount of text data.

# %% [markdown]
# **Step 2 Answer**
#
# XGBooster Classifier is a modern Machine Learning alogrithm designed for eXtreme Gradient Boosting and is based on decision trees, In this project we will be using xgboost library to implement XGBooster Classifier.

# %% [markdown]
# **Step 3**
#
# Write one paragraph describing the model or models you plan to use.  Why did you pick this model or models?  How will they answer your research question?  What metrics will you use to evaluate the model performance?

# %% [markdown]
# **Step 3 Answer**
#
# In this project, I applied the Logistic Regression, Decision Tree, Random forest Information Gain, Random Forest Entropy, SVM, KNeighbor Classifier, Gaussian Naive Classifier, and Bernuolli Classifier, and Voting Classfiers was applied to optimize the accuracy and the evaluation of the models; which will work the best. Based on accuracy, Random Forest Entropy worked well, but I created a Machine Learning model using XGBClassifier to Detect Parkinsons Disease with extreme Gradient Boosting (XGBoost) because accuracy alone is not enough to evaluate the healthcare models since false negative can be very problematic; for instance, person will have disease when diagnosed negative. Also, false positive can be a huge issue in sense of medication; person will be starting the medication when it is not needed.

# %% [markdown]
# ##Task 5: Data Wrangling
#
# Use the following code block (feel free to add more) to do any data wrangling.  It may be helpful to refer to the questions you answered previously in the Exploratory Data Analysis section.  For reference, they are:
#
# Here are some questions to consider:
#
# * How many observations does your data set have? 1,596
# * How many features does your data set have? 23
# * Does your data have any missing values? None
#
# * If your data has missing values, will you drop the records or impute the * missing data? What will your imputation strategy be?
#
#   I have dropped the name column only since it should not be the part of the model evaluation.
#
# * Does your data have any outliers or unusual values? If so, how will you handle them?
#
#   All the numerical columns and the NHR has many outliers; however, according to the research paper researchers says that these values are acceptable hence do not remove them. The variable "status" has an outlier but status is a dependent variable, so we can not remove it.
# * Will you need to do any feature engineering or drop any features from your data? I had drop the name, and it is only feature I dropped.
# * Will you need to encode any categorical data or standardize or normalize quantitative features? Yes
# * Will you need to split your data into traning and testing sets? Yes
# * Will you need to do any pre-processing of text data? Yes

# %%
# Darker the color means higher correlation 
# Lighter the color means lower correlation
plt.figure(figsize=(18,18))
corr = parkinsons_data.corr()
sns.heatmap(corr,annot = True,cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# What is correlation? It the effect of one variable on the other variable. Correlation has a huge effect on the output of the algorithms.
# In this case, the dependent variable is the status which is obviously 1 when a person has parkinsons and zero when person does not has parkinsons.
# There should not be high correlation between the independent variables.

# %%
# For the quick galance
# Darker the color means higher correlation 
# Lighter the color means lower correlation

sns.heatmap(parkinsons_data.corr(), cmap='YlGnBu')
plt.show()

# %%
# Visual null values
sns.heatmap(parkinsons_data.isna(),cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# Missing values in each column (there are no null values)
parkinsons_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# distribution of target Variable
# 1 means parkinsons diagnosed
# 0 means no parkinsons
parkinsons_data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
# grouping the data based on the target variable
parkinsons_data.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
# Distribution of data
# The data frame columns are converted into a list, so we don't have to do it for every column separately
# We need to find the distribution in order to check if the alogrithm can be applicable to the entire data.
# Ideally, data sample should follow the Normal Distribution or a Guassian Distribution, and in our case, it is following Guassian Distribution. 
# As we can see distortion, and there is certain skewness and kurtosis towards right which can be fixed.
# There are some double curves, but mostly they are normally distributed.


def distplots(col):
    sns.distplot(parkinsons_data[col])
    plt.show()

for i in list(parkinsons_data.select_dtypes(exclude=["object"]).columns)[1:]:
    distplots(i)

# %% [markdown]
# # ***Outliers/ Find the distribution of data (Summary based on the boxplots and the research paper findings)***
# 1. All the numerical columns and the NHR has many outliers; however, according to the research paper researchers says that these values are acceptable hence do not remove them
# 2. Status has an outlier but status is a dependent variable, so we can not remove it.
# 3. In conclusion, there is no actual outlier based on the research paper findings, so we will not remove them.

# %%
# Outliers/ Find the distribution of data (Summary based on the boxplots and the research paper findings)
# All the numerical columns and the NHR has many outliers; however, according to the research paper researchers says that these values are acceptable hence do not remove them
# status has an outlier but status is a dependent variable, so we can not remove it.
# In conclusion, there is no actual outlier based on the research paper findings, so we will not remove them.
def boxplots(col):
    sns.boxplot(parkinsons_data[col])
    plt.show()
for i in list(parkinsons_data.select_dtypes(exclude=["object"]).columns)[1:]:
    boxplots(i)

# %%
# box and whiskers plot
parkinsons_data.plot(kind='box', subplots=True, layout=(5,5), figsize=(10,10))
plt.show()

# %%
# Data Pre-Processing
# status is a dependent variable denoted by Y
# X is the independent variable
# name is the id column, and we have to drop the name column because it should not be part of the algorithm 
X = parkinsons_data.drop(columns=['name','status'], axis=1)
Y = parkinsons_data['status']

# %%
# People have parkinsons will be 1 and who do'not have it will be 0
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %% [markdown]
# ##Task 6: Modeling
#
# Use the following code block to build your ML model.

# %%
# Split data to Training data and Test data 
# we are creating the four arrays and we will using the train test split function. 
# X function will be split into two arrays and one array will be the Training data and other one will be Test data
# Y function will be split into two arrays and one array will be the Training data and other one will be Test data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# 
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
# Data Standardization

scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.80172872 -0.70830513 -0.10603303 ...  0.89854281 -0.48294197
#    1.64980971]
#  [-1.04374224 -0.74950432 -0.29919921 ...  1.17531845  0.65177741
#    0.26864313]
#  [-0.3790498   0.13122544 -0.82039362 ... -0.7771489  -0.73102398
#    0.28542547]
#  ...
#  [-0.13744368 -0.31583967  0.56292775 ... -1.65126173 -0.08248373
#   -0.17764131]
#  [-0.14053505 -0.42034011  0.39263744 ...  0.19569946  1.19665768
#   -0.11105606]
#  [-0.35427092  4.57536567 -1.22354854 ...  0.55494177  0.80279984
#    2.57800238]]

# %%
from matplotlib.cbook import flatten
from pandas.core.reshape.melt import lreshape
# Algorithm Applications
from sklearn.metrics import f1_score, precision_score, recall_score
list_met = []
list_accuracy = []

# Applying Logistic Regression

classifier = LogisticRegression(C=0.4, max_iter= 1000, solver = 'liblinear')
lr = classifier.fit(X_train,Y_train)
# Prediction
Y_predict= classifier.predict(X_test)
#Accuracy
accuracy_LR = accuracy_score(Y_test, Y_predict)

# Applying Decision Tree

classifier2 = DecisionTreeClassifier(random_state=14)
dt = classifier2.fit(X_train, Y_train)
# Prediction
Y_predict2= classifier2.predict(X_test)
#Accuracy
accuracy_DT = accuracy_score(Y_test, Y_predict2)

# Apply Random Forest Criteria = information gain

classifier3 = RandomForestClassifier(random_state=14)
rfi = classifier3.fit(X_train, Y_train)
# Prediction
Y_predict3= classifier3.predict(X_test)
#Accuracy
accuracy_RFI = accuracy_score(Y_test, Y_predict3)

# Applying Random Forest Crieteria = entropy

classifier4 = RandomForestClassifier(criterion='entropy')
rfe = classifier4.fit(X_train, Y_train)
# Prediction
Y_predict4= classifier4.predict(X_test)
#Accuracy
accuracy_RFE = accuracy_score(Y_test, Y_predict4)

# Apply SVM

# Model Training
# Support Vector Machine Model
model_svm = SVC(cache_size=100)
# training the SVM model with training data
svm = model_svm.fit(X_train, Y_train)
# Prediction
Y_predict5= model_svm.predict(X_test)
# Accuracy
accuracy_svc = accuracy_score(Y_test, Y_predict5)

# Apply KNN

model_knn3 = KNeighborsClassifier(n_neighbors=3)
knn = model_knn3.fit(X_train, Y_train)
# Prediction 
pred_knn3 = model_knn3.predict(X_test)
# Accuracy
accuracy_SVM = accuracy_score(Y_test, pred_knn3)

# Apply Gaussian Naive Bayes

gnb = GaussianNB()
gnb = gnb.fit(X_train, Y_train)
#Predicting Test Set
pred_gnb = gnb.predict(X_test)
# Accuracy
accuracy_GNB = accuracy_score(Y_test, pred_gnb)

# Apply Bernoulli Naive Bayes

model = BernoulliNB()
bnb = model.fit(X_train, Y_train)
# Predicting Test set
pred_bnb = model.predict(X_test)
# Accuracy
accuracy_BNB = accuracy_score(Y_test, pred_bnb)

# Combining all the modles using voting classifier

evc = VotingClassifier(estimators=[('lr', lr), ('rfi', rfi), ('rfe', rfe), ('DT', dt), 
                                   ('svm', svm),('knn', knn), ('gnb', gnb), ('bnb', bnb)], voting = 'hard',
                                    flatten_transform = True)
model_evc = evc.fit(X_train, Y_train)
# Predicting Test Set
pred_evc = evc.predict(X_test)
# Accuracy
accuracy_evc = accuracy_score(Y_test, pred_gnb)

list1 = ['Logistic Regression', 'Decision Tree', 'Random Forest (info gain)', 'Random Forest (Entropy)', 'SVM', 'KNN', 'gnb', 'bnb', 'Voting Classifier']
list2 = [accuracy_LR, accuracy_DT, accuracy_RFI, accuracy_RFE, accuracy_svc, accuracy_SVM, accuracy_GNB, accuracy_BNB, accuracy_evc]
list3 = [classifier, classifier2, classifier3, classifier4, model_svm, model_knn3, gnb, model]

parkinsons_data_Accuracy = pd.DataFrame({'Method Used':list1, 'Accuracy': list2})
print(parkinsons_data_Accuracy)

chart = sns.barplot(x= 'Method Used', y='Accuracy', data= parkinsons_data_Accuracy)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
print(chart)
# Out:
#                  Method Used  Accuracy
# 0        Logistic Regression  0.923077
# 1              Decision Tree  0.897436
# 2  Random Forest (info gain)  0.923077
# 3    Random Forest (Entropy)  0.923077
# 4                        SVM  0.897436
# 5                        KNN  0.923077
# 6                        gnb  0.717949
# 7                        bnb  0.717949
# 8          Voting Classifier  0.717949
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# # ***Comparsion of different Classifiers and Models***
#
# Information gain method, entropy method, and svm are performing the best in terms of accuracy; however, accuracy is not enough in healthcare. We want to find true positive and true negative to make sure patient get the right treatment.
#
# Impact of false negative will be that we will predict that person will not suffer with the parkinsons, and person will be suffering from parkinsons.
#
# Impact of false positive will be that peron will get the medication which is not needed.
#
# Therefore, we need to do further evaluations which should lead to the true positive and true negative. For further evaluations, we will be using the XG Booster Classifier.

# %% [markdown]
# # ***Initialization and Model Training for XGBClassifier***

# %%
# Initialization and Model Training for XGBClassifier
# This is used to classify the extereme Gradient Booting using alogrithms for modern data science problems
# after using this, we will be able to trauin and predict using many models to produce one superior output.
model_xg = XGBClassifier()
model_xg.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
# Predict values for the X_test and calculate the accuray of the model
y_pred = model_xg.predict(X_test)
print(accuracy_score(Y_test, y_pred)*100)
# Out:
# 94.87179487179486

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, model_xg.predict(X_test))

# %%
f1_score(Y_test, model_xg.predict(X_test), average ='binary')
# Out:
# 0.9696969696969697

# %%
print(classification_report(Y_test, model_xg.predict(X_test)))
print('ConfusionMatrix')
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.86      0.90        39
# weighted avg       0.95      0.95      0.95        39
#
# ConfusionMatrix
# [[ 5  2]
#  [ 0 32]]

# %%
for i in list3:
    print("************************************************",i,"*************************************************")
    print(classification_report(Y_test, i.predict(X_test)))
    print('Confusion Matrix:')
    print(confusion_matrix(Y_test, i.predict(X_test)))
    print()
# Out:
# ************************************************ LogisticRegression(C=0.4, max_iter=1000, solver='liblinear') *************************************************
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73         7
#            1       0.91      1.00      0.96        32
#
#     accuracy                           0.92        39
#    macro avg       0.96      0.79      0.84        39
# weighted avg       0.93      0.92      0.91        39
#
# Confusion Matrix:
# [[ 4  3]
#  [ 0 32]]
#
# ************************************************ DecisionTreeClassifier(random_state=14) *************************************************
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.94      0.94      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.83      0.83      0.83        39
# ...

# %%
# Visualization of the performance with ROC 
# Calculate the fpr and tpr for all threshold of the classification
def plot_roc(model, X_test, Y_test):
    probabilities = model.predict_proba(np.array(X_test))
    predictions = probabilities
    fpr, tpr, threshold = roc_curve(Y_test, predictions[:,1])
    roc_auc = auc(fpr, tpr)

    plt.title('Recevier Perating Characteristics')
    plt.plot(fpr, tpr, 'b', label='Auc = %0.2f' % roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1], [0,1],'r--')
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# ##Task 7: Evaluation
#
# Use the following code block to evaluate your ML model.

# %%
plot_roc(model_xg,X_test,Y_test)

# %%
for i in range(0, len(list3)):
    try:
        print()
        print("----  ------ROC FOR", list1[i],"+ PCA ----------------")
        plot_roc(list3[i], X_test, np.array(Y_test))
        print()
    except:
        print("roc not valid")
# Out:
# ----  ------ROC FOR Logistic Regression + PCA ----------------
# ----  ------ROC FOR Decision Tree + PCA ----------------
# ----  ------ROC FOR Random Forest (info gain) + PCA ----------------
# ----  ------ROC FOR Random Forest (Entropy) + PCA ----------------
# ----  ------ROC FOR SVM + PCA ----------------
# roc not valid
#
# ----  ------ROC FOR KNN + PCA ----------------
# ----  ------ROC FOR gnb + PCA ----------------
# ----  ------ROC FOR bnb + PCA ----------------

# %% [markdown]
# # ***Data Evaluation***
#
# According to the ROC Matrix Random forest Entropy is the best model so far since it has only one false positive and zero false negative.
#
# On the other hand, Logistic Regression is good in sense that it has no false negative which can be crucial in healthcare; however, it has 3 false positive values. SVC is good in sense that it has no false negative, but it has 4 false positive values.
#
# Besides, Bernoulli and Gaussian Naive are not good since they have many false positive and false negative values.

# %% [markdown]
# **Step 3**
#
# Using visualizations or summary data, show that the requirements you listed in Step 2 are met by your data.  Feel free to add code blocks as necessary.

# %% [markdown]
# **Step 4**
#
# Explore your data to determine what kind of data cleaning or wrangling will be necessary before you run your ML model.
#
# Here are some questions to consider:
# * How many observations does your data set have?
# * How many features does your data set have?
# * Does your data have any missing values?
# * If your data has missing values, will you drop the records or impute the missing data?  What will your imputation strategy be?
# * Does your data have any outliers or unusual values?  If so, how will you handle them?
# * Will you need to do any feature engineering or drop any features from your data?
# * Will you need to encode any categorical data or standardize or normalize quantitative features?
# * Will you need to split your data into traning and testing sets?
# * Will you need to do any preprocessing of text data?
#
# If you aren’t sure how to answer any of these questions, your instructor can give you guidance and suggestions.

# %% [markdown]
# **At this point, it is possible that you will discover that you can't answer your research question with your data set.  Work with your instructor to either modify your research question, select a backup research question, or select a new data set. To complete this task successfully, you will need to have selected a research question, have a data set that can be used to answer it, AND have performed EDA.**

# %% [markdown]
# **Step 1**
#
# Write about one paragraph of background to give your audience some context for your research question.  What motivated you to ask this specific research question?  What is the real world application?  Think about your stakeholder(s) and what that person would want to know about the topic before you got started.

# %% [markdown]
# **Step 2**
#
# Write one or two paragraphs describing your data set.  What was the source of the data?   Why did you choose to use this particular data set?  Did you experience any challenges with accessing or loading the data?  Describe any data wrangling you need to do to run your ML model.

# %% [markdown]
# **Step 2 Answer**
# # ***Data Collection***
# Data is collected from Kaggle.com, https://www.kaggle.com/code/siddharthtyagi/parkinson-s-diseases-detection . It was in data format; I converted into CSV format.
# The Dataset was created by Max Little of the University of Oxford, In collaboration for Voice and Speech, Denver, Colorado, who recorded the speech signals.
#
# # ***Characteristics of the Dataset***
#
# Title: Parkinsons Disease Data Set
#
# Abstract: Oxford Parkinson's Disease Detection Dataset
#
# Area: Life
#
# Data Set Characteristics: Multivariate
#
# Data has 1,596 observations and 25 comments
#
# Number of instances or rows 195
#
# Data File size 40 KB
#
# Version 1 of 1
#
# Attribute Characteristics: Real
#
# Number of Attributes: 23
#
# Date Donated: 2008-06-26
#
# Missing Values? Not Applicable
#
# Associated Tasks: Classification
#
# Data Wrangling was important since we need to see if there are any null values or outliers. Besides, in this data info there is no null value; however, we have to check it in order to validate the information. After, applying the heat maps we see no null values. In this case study outliers are not a problem.All the numerical columns and the NHR has many outliers; however, according to the research paper researchers says that these values are acceptable hence do not remove them. The variable "status" has an outlier but status is a dependent variable, so we can not remove it.
# # ***Steps of the data wrangling are stated below:***
#
# Importing dependencies
#
# Loading the dataset
#
# Checking number of rows and columns
#
# Getting information about the data
#
# Checking for null values
#
# Getting statistical measures
#
# Checking for the data distribution
#
# Grouping the data based on the target value
#
# Identified the independent variables and the dependent variables
#
# Train Test split: I tried various randon states with it I found out State 14  and 42 work the best
#
# Data Standardization
#
# Model Training
#
# Model Evaluation

# %% [markdown]
# ##Task 8: Results
#
# Use the following text block to summarize your results.  How will you communicate the answer to your research question to stakeholders?

# %% [markdown]
# **Step 4**
#
# Think about your intended audience.  How will you communicate your results to your stakeholders?  What data storytelling techniques will you use in your presentation to engage your audience?
#
# My grandmother suffered with parkinsons, and I saw her struggling in her old age. Not only that as I grew up, I realized that it runs in my family and from my father and my mother side. It is important that patients should get the treament as soon as possible, so symptoms and the severity of the Parkinsons disease should be minimized. Diagnosis of the disease highly based on the data evaluation. There is no room false negatives values in the data analysis, and flase positives can be problematics too.
#
# Accorning to the ROC Matrix Random forest Entropy is the best model so far since it has only one false positive and zero false negative.
#
# On the other hand, Logistic Regression is good in sense that it has no false negative which can be crucial in healthcare; however, it has 3 false positive values. SVC is good in sense that it has no false negative, but it has 4 false positive values.
#
# Besides, Bernoulli and Gaussian Naive are not good since they have many false positive and false negative values.

# %% [markdown]
# #Part 2: Presentation

# %% [markdown]
# ##Task 1: Slide Deck
#
# Create and present a slide deck to your classmates showing how you answered your research question.  You can find a Slide Template in the course materials or create your own.  The presentation should be about five minutes long.

# %% [markdown]
# ##Task 2: Reflection
#
# Use the following text block to reflect on the project.  Did you run into anything that was particularly difficult?  What part(s) of the project did you enjoy most?  Did your results leave you with any new questions you'd investigate if you had more time?

# %% [markdown]
# **Task 2 Answer**
#
# Write your answer to Task 5 here.
